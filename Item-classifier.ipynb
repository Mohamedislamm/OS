# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import os

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

# %% [markdown]
# This code classifies inventory items by:
#
# First giving unique IDs to exact matches (same UOM + Class + Category + Description)
#
# Then grouping similar descriptions together using text clustering
#
# Result: Every item gets an ID, with similar items sharing the same ID
#
# Prints all items grouped by their final IDs
#
# Saves results to Excel file

# %%
class ItemClassifier:
    def __init__(self, eps=0.2, min_samples=2):
        self.eps = eps
        self.min_samples = min_samples

    def preprocess_text(self, text):
        """Clean and normalize text for similarity comparison"""
        if pd.isna(text):
            return ""
        text = str(text).lower()
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\s+', ' ', text)
        words = text.split()
        return ' '.join(sorted(words))

    def load_and_validate_data(self, file_path):
        """Load Excel file and validate required columns"""
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"File '{file_path}' not found")

        df = pd.read_excel(file_path)
        df.columns = df.columns.str.strip()

        required_columns = [
            'Item Primary UOM', 'Item Class', 'Category',
            'Item', 'Item Desc'
        ]
        missing_columns = [col for col in required_columns if col not in df.columns]
        if missing_columns:
            raise ValueError(f"Missing required columns: {missing_columns}")

        return df

    def assign_exact_match_ids(self, df):
        """Assign IDs to items with exact matches"""
        df['clean_desc'] = df['Item Desc'].apply(self.preprocess_text)
        df['group_key'] = df['Item Primary UOM'] + '|' + df['Item Class'] + '|' + df['Category']
        df['Item ID'] = 0

        unique_items = df.drop_duplicates(
            subset=['Item Primary UOM', 'Item Class', 'Category', 'clean_desc']
        )

        current_id = 1
        for _, row in unique_items.iterrows():
            mask = (
                (df['Item Primary UOM'] == row['Item Primary UOM']) &
                (df['Item Class'] == row['Item Class']) &
                (df['Category'] == row['Category']) &
                (df['clean_desc'] == row['clean_desc'])
            )
            df.loc[mask, 'Item ID'] = current_id
            current_id += 1

        return df, current_id

    def group_similar_items(self, df):
        """Group similar items using DBSCAN clustering"""
        for group_key in df['group_key'].unique():
            group_mask = df['group_key'] == group_key
            group_df = df[group_mask].copy()
            group_texts = group_df['clean_desc'].tolist()

            if len(group_texts) > 1:
                vectorizer = TfidfVectorizer(max_features=500, stop_words='english')
                X = vectorizer.fit_transform(group_texts)

                dbscan = DBSCAN(
                    eps=self.eps,
                    min_samples=self.min_samples,
                    metric='cosine'
                )
                clusters = dbscan.fit_predict(X.toarray())

                cluster_mapping = {}
                for i, cluster in enumerate(clusters):
                    if cluster != -1:
                        item_idx = group_df.index[i]
                        original_id = df.at[item_idx, 'Item ID']

                        if cluster not in cluster_mapping:
                            cluster_mapping[cluster] = original_id
                        else:
                            df.at[item_idx, 'Item ID'] = cluster_mapping[cluster]

        return df

    def classify_items(self, file_path):
        """Main classification pipeline"""
        df = self.load_and_validate_data(file_path)
        df, _ = self.assign_exact_match_ids(df)
        df = self.group_similar_items(df)

        # Clean up temporary columns
        df = df.drop(['clean_desc', 'group_key'], axis=1, errors='ignore')
        return df


def print_results(result_df):
    """Print formatted results"""
    print("=" * 60)
    print("ITEM CLASSIFICATION RESULTS")
    print("=" * 60)

    for item_id in sorted(result_df['Item ID'].unique()):
        cluster_items = result_df[result_df['Item ID'] == item_id]
        print(f"\n📦 ITEM GROUP {item_id} ({len(cluster_items)} items):")
        print("-" * 50)

        for _, row in cluster_items.iterrows():
            print(f"   • {row['Item']} - {row['Item Desc']}")


def main():
    file_path = "itemdetails report_items.xlsx"
    classifier = ItemClassifier(eps=0.2, min_samples=2)

    try:
        print("Starting item classification...")
        result_df = classifier.classify_items(file_path)

        print_results(result_df)

        # Save results
        result_df.to_excel("Classified items.xlsx", index=False)

        print("\n" + "=" * 60)
        print(f"Results saved to: Classified item.xlsx")
        print(f"Total unique item groups: {len(result_df['Item ID'].unique()):,}")
        print(f"Total items processed: {len(result_df):,}")
        print("=" * 60)

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except ValueError as e:
        print(f"Validation Error: {e}")
    except Exception as e:
        print(f"Unexpected error: {e}")


if __name__ == "__main__":
    main()
# Out:
# Starting item classification...
# ============================================================
# ITEM CLASSIFICATION RESULTS
# ============================================================
#
# 📦 ITEM GROUP 0 (1 items):
# --------------------------------------------------
#    • nan - nan
#
# 📦 ITEM GROUP 1 (1 items):
# --------------------------------------------------
#    • 001436 - FITTING 6MM
#
# 📦 ITEM GROUP 2 (1 items):
# --------------------------------------------------
#    • 01-010-0004 - CYLINDER BLOCK
#
# 📦 ITEM GROUP 3 (1 items):
# --------------------------------------------------
#    • 0119811305 - BEARING 6205ZZC3
#
# 📦 ITEM GROUP 4 (1 items):
# --------------------------------------------------
#    • 02-020-0022 - VALVE PLATE
#
# 📦 ITEM GROUP 5 (1 items):
# --------------------------------------------------
#    • 02-023-0004 - RET PLATE
#
# 📦 ITEM GROUP 6 (1 items):
# --------------------------------------------------
#    • 020-1053 - GSM ANTENNA AND GPS ANTENNA
#
# 📦 ITEM GROUP 7 (8 items):
# --------------------------------------------------
#    • 02051604 - AIR FILTER OUTER
#    • 1209590 - AIR FILTER OUTER
#    • 191526 - AIR FILTER OUTER
#    • 191526 - AIR FILTER OUTER
#    • 2051200 - AIR FILTER OUTER
#    • 2216429 - AIR FILTER OUTER
#    • A-89090 - AIR FILTER OUTER
#    • YA00007394LHE - AIR FILTER OUTER
#
# 📦 ITEM GROUP 8 (7 items):
# --------------------------------------------------
#    • 02051606 - AIR FILTER INNER
#    • 1209620 - AIR FILTER INNER
#    • 191525 - AIR FILTER INNER
#    • 191525 - AIR FILTER INNER
#    • 2051202 - AIR FILTER INNER
#    • 2051202 - AIR FILTER INNER
#    • 2216432 - AIR FILTER INNER
#
# 📦 ITEM GROUP 9 (1 items):
# --------------------------------------------------
#    • 03-030-0003 - PISTON
#
# 📦 ITEM GROUP 10 (1 items):
# --------------------------------------------------
#    • 0539726030 - Spring
#
# 📦 ITEM GROUP 11 (1 items):
# --------------------------------------------------
#    • 06030-06004 - BEARING WATER PUMP
#
# 📦 ITEM GROUP 12 (1 items):
# --------------------------------------------------
#    • 06030-06304 - Bearing Ball
#
# 📦 ITEM GROUP 13 (1 items):
# --------------------------------------------------
#    • 09-090-0002 - SCREW
#
# 📦 ITEM GROUP 14 (1 items):
# --------------------------------------------------
#    • 10-0026-01-0023 - CORRUGATED SHEET 0.35MMX1MX6MTR
#
# 📦 ITEM GROUP 15 (1 items):
# --------------------------------------------------
#    • 10-0026-02-0054 - HOT ROLLED SHEET 2MMX122X244CM
#
# 📦 ITEM GROUP 16 (1 items):
# --------------------------------------------------
#    • 10-0026-02-0058 - HOT ROLLED SHEET 20MMX122X244
#
# 📦 ITEM GROUP 17 (1 items):
# --------------------------------------------------
#    • 10-0031-01-0005 - ANGLE BAR-6MMX8CMX8CMX12M
#
# 📦 ITEM GROUP 18 (1 items):
# --------------------------------------------------
#    • 10-0031-03-0035 - U-CHANNEL 6MMX14CMX6CMX6M
#
# 📦 ITEM GROUP 19 (1 items):
# --------------------------------------------------
#    • 10-0031-03-0048 - C-CHANNEL 6MMX12CMX6MTR
#
# 📦 ITEM GROUP 20 (1 items):
# --------------------------------------------------
#    • 10-0031-05-0043 - FLAT BAR 10MMX15CMX6M
#
# 📦 ITEM GROUP 21 (1 items):
# --------------------------------------------------
#    • 10-0031-05-0048 - FLAT BAR 50X5MMX6-MTR
#
# 📦 ITEM GROUP 22 (1 items):
# --------------------------------------------------
#    • 10-0031-08-0022 - RECTANGULAR TUBE 2MMX40X80X6MTR
#
# 📦 ITEM GROUP 23 (1 items):
# --------------------------------------------------
#    • 10-0031-08-0035 - RECTANGULAR TUBE 2MMX30MMX60MMX6MTR
#
# 📦 ITEM GROUP 24 (1 items):
# --------------------------------------------------
#    • 10-0031-10-0008 - SQUARE TUBE 2MMX40X40X6MTR
#
# 📦 ITEM GROUP 25 (1 items):
# --------------------------------------------------
#    • 10-0031-10-0024 - SQUARE TUBE 2MMX50X50X6MTR
#
# 📦 ITEM GROUP 26 (1 items):
# --------------------------------------------------
#    • 10-0031-10-0026 - SQUARE TUBE 2MMX60X60X6MTR
#
# 📦 ITEM GROUP 27 (1 items):
# --------------------------------------------------
#    • 10-0031-10-0031 - SQUARE TUBE 2MMX70X70X6MTR
#
# 📦 ITEM GROUP 28 (1 items):
# --------------------------------------------------
#    • 10-0031-11-0032 - STEEL PLATE  5MM 1X2MTR-SP-5MMX1X2MTR
#
# 📦 ITEM GROUP 29 (1 items):
# --------------------------------------------------
#    • 10-0031-11-0169 - CHECKERED PLATE 2MMX122X244CM
#
# 📦 ITEM GROUP 30 (3 items):
# --------------------------------------------------
#    • 10-0051-00-0387 - GROUND GRANULATED BLAST FURNACE SLAG (GGBFS) - 213UAES150U
#    • 10-0051-00-0883 - GROUND GRANULATED BLAST FURNACE SLAG (GGBFS) - 213UAES150U
#    • 10-0051-00-0883 - GROUND GRANULATED BLAST FURNACE SLAG (GGBFS) - 213UAES150U
#
# 📦 ITEM GROUP 31 (1 items):
# --------------------------------------------------
#    • 10-0051-00-0427 - SIKAMENT-850
#
# 📦 ITEM GROUP 32 (1 items):
# --------------------------------------------------
#    • 10-0051-00-0714 - PLASTOCRETE -N-L-414596
#
# 📦 ITEM GROUP 33 (2 items):
# --------------------------------------------------
#    • 10-0051-00-0885 - CONPLAST SP-440 (1000L) BULK-1317901-B
#    • 10-0051-00-0885 - CONPLAST SP-440 (1000L) BULK-1317901-B
#
# 📦 ITEM GROUP 34 (3 items):
# --------------------------------------------------
#    • 10-0051-00-0888 - FLY ASH TYPE -F "HITECH"-211INDHTC
#    • 10-0051-00-0888 - FLY ASH TYPE -F "HITECH"-211INDHTC
#    • 10-0051-00-0888 - FLY ASH TYPE -F "HITECH"-211INDHTC
#
# 📦 ITEM GROUP 35 (1 items):
# --------------------------------------------------
#    • 10-0051-00-0964 - SIKAPLASTIMENT-PR150-414587
#
# 📦 ITEM GROUP 36 (1 items):
# --------------------------------------------------
#    • 10-0051-00-0985 - FLOCRETE SP137 (1000LTR/PACK)-SP137
#
# 📦 ITEM GROUP 37 (4 items):
# --------------------------------------------------
#    • 10-0051-00-1057 - SIKAMENT RB 858M-51991399
#    • 10-0051-00-1057 - SIKAMENT RB 858M-51991399
#    • 10-0051-00-1057 - SIKAMENT RB 858M-51991399
#    • 10-0051-00-1057 - SIKAMENT RB 858M-51991399
#
# 📦 ITEM GROUP 38 (3 items):
# --------------------------------------------------
#    • 10-0051-00-1058 - SIKA PLASTIMENT RMC 4-50460982
#    • 10-0051-00-1058 - SIKA PLASTIMENT RMC 4-50460982
#    • 10-0051-00-1058 - SIKA PLASTIMENT RMC 4-50460982
#
# 📦 ITEM GROUP 39 (2 items):
# --------------------------------------------------
#    • 10-0051-00-1059 - VISCOCRETE 504 S
#    • 10-0051-00-1059 - VISCOCRETE 504 S
#
# 📦 ITEM GROUP 40 (1 items):
# --------------------------------------------------
#    • 10-0051-00-1067 - INJECTABLE MORTAR HIT-RE 100
#
# 📦 ITEM GROUP 41 (1 items):
# --------------------------------------------------
#    • 10-0051-00-1140 - CHRYSO FLUID SA-221
#
# 📦 ITEM GROUP 42 (1 items):
# --------------------------------------------------
#    • 10-0061-00-0205 - Circut Braker 200amp 3ph-091070108
#
# 📦 ITEM GROUP 43 (1 items):
# --------------------------------------------------
#    • 10-0061-00-0914 - MCB 3POLE 63A-MCB3P63
#
# 📦 ITEM GROUP 44 (1 items):
# --------------------------------------------------
#    • 10-0061-00-1267 - Sleeve 6mm-SL-6MM
#
# 📦 ITEM GROUP 45 (1 items):
# --------------------------------------------------
#    • 10-0061-00-1281 - Sleeve4-SL-4
#
# 📦 ITEM GROUP 46 (1 items):
# --------------------------------------------------
#    • 10-0061-00-1282 - Sleeve5-SL-5
#
# 📦 ITEM GROUP 47 (1 items):
# --------------------------------------------------
#    • 10-0061-00-2091 - SLEEVE NO.2  (FOR MAGNETIC WIRE ELEC MOTOR REWINDING)
#
# 📦 ITEM GROUP 48 (1 items):
# --------------------------------------------------
#    • 10-0061-00-2092 - SLEEVE NO.3  (FOR MAGNETIC WIRE ELEC MOTOR REWINDING)
#
# 📦 ITEM GROUP 49 (1 items):
# --------------------------------------------------
#    • 10-0061-00-5694 - SLEEVE 1MM (FOR MAGNETIC WIRE ELEC MOTOR REWINDING)
#
# 📦 ITEM GROUP 50 (1 items):
# --------------------------------------------------
#    • 10-0061-00-6038 - FAN (INVERTER) - U60T24MS7A7-51(6025)
#
# 📦 ITEM GROUP 51 (1 items):
# --------------------------------------------------
#    • 10-0061-00-6039 - TRANSFORMER FROM 380 TO 220 -NDK (BK250)
#
# 📦 ITEM GROUP 52 (1 items):
# --------------------------------------------------
#    • 10-0061-01-0241 - CONNECTION WIRE 4MM2
#
# 📦 ITEM GROUP 53 (1 items):
# --------------------------------------------------
#    • 10-0061-02-0008 - AUTO WIRE 1.0MM - E-AW-1.0MM
#
# 📦 ITEM GROUP 54 (1 items):
# --------------------------------------------------
#    • 10-0061-02-0009 - AUTO WIRE 1.5MM - E-AW-1.5MM
#
# 📦 ITEM GROUP 55 (1 items):
# --------------------------------------------------
#    • 10-0061-02-0010 - AUTO WIRE 2.5MM - E-AW-2.5MM
#
# 📦 ITEM GROUP 56 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0018 - CABLE, ELECTRIC - (4CX35MM)(CU/XLPE/SWA/PVC/1KV-E-EC-4CX35MM
#
# 📦 ITEM GROUP 57 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0073 - CABLE ELECTRIC "1CX120MM"-ELE-EC-120MMX1C
#
# 📦 ITEM GROUP 58 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0212 - Electricable Cable 10mm-ELECT-3CX10MM
#
# 📦 ITEM GROUP 59 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0300 - FLEXIBLE CABLE 3CX16MM-E-EC-3CX16MM
#
# 📦 ITEM GROUP 60 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0568 - CABLE, FLEXIBLE 1CX70MM2 CU ,PVC (G.YELLOW GREEN)
#
# 📦 ITEM GROUP 61 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0732 - CABLE FLEXIBLE 1X240MM
#
# 📦 ITEM GROUP 62 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0755 - CABLE, FLEXIBLE 3CX16MM
#
# 📦 ITEM GROUP 63 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0756 - CABLE, FLEXIBLE 3CX10MM
#
# 📦 ITEM GROUP 64 (2 items):
# --------------------------------------------------
#    • 10-0061-04-0757 - CABLE, FLEXIBLE 3CX4MM
#    • 10-0061-04-0757 - CABLE, FLEXIBLE 3CX4MM
#
# 📦 ITEM GROUP 65 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0758 - CABLE, FLEXIBLE 24CX2.5MM
#
# 📦 ITEM GROUP 66 (1 items):
# --------------------------------------------------
#    • 10-0061-04-0759 - CABLE FLEXIBLE 1CX16MM
#
# 📦 ITEM GROUP 67 (1 items):
# --------------------------------------------------
#    • 10-0061-06-0137 - Mccb (Circuit Breaker) 100amp-E-MCCB-100AMP
#
# 📦 ITEM GROUP 68 (1 items):
# --------------------------------------------------
#    • 10-0061-06-0162 - Motor Circuit Breaker 30-40a-GRAN-GV3P40
#
# 📦 ITEM GROUP 69 (1 items):
# --------------------------------------------------
#    • 10-0061-06-0167 - Motor Circuit Breaker 48-65a-GV3P65
#
# 📦 ITEM GROUP 70 (1 items):
# --------------------------------------------------
#    • 10-0061-08-0119 - Contactor 3p Ac3 40amp-220v-LC1D40AM
#
# 📦 ITEM GROUP 71 (1 items):
# --------------------------------------------------
#    • 10-0061-08-0129 - Contactor 65a Op-30096-LC1D65AM7
#
# 📦 ITEM GROUP 72 (1 items):
# --------------------------------------------------
#    • 10-0061-14-0091 - Push Button Switch (Green)-XB4BA31-G
#
# 📦 ITEM GROUP 73 (1 items):
# --------------------------------------------------
#    • 10-0061-14-0199 - Switch, Push Button 'Red'-69XB4BA42
#
# 📦 ITEM GROUP 74 (1 items):
# --------------------------------------------------
#    • 10-0061-16-0105 - MAGNETIC WIRE (1.40MM)-E-MW-1.40MM
#
# 📦 ITEM GROUP 75 (1 items):
# --------------------------------------------------
#    • 10-0071-00-0749 - Cotton Big(500g/Roll)-PTS-0029
#
# 📦 ITEM GROUP 76 (1 items):
# --------------------------------------------------
#    • 10-0071-00-0759 - COTTON TAPE 1"-854322
#
# 📦 ITEM GROUP 77 (1 items):
# --------------------------------------------------
#    • 10-0071-00-1640 - MAGNETIC WIRE 1.30MM-E-MW-1.30MM
#
# 📦 ITEM GROUP 78 (1 items):
# --------------------------------------------------
#    • 10-0071-00-1812 - NITROGEN GAS -(RE-FILLED)-NIT-0002
#
# 📦 ITEM GROUP 79 (1 items):
# --------------------------------------------------
#    • 10-0071-00-3554 - WINTER JACKET-WJ-10012
#
# 📦 ITEM GROUP 80 (3 items):
# --------------------------------------------------
#    • 10-0071-00-3770 - ACETELYNE GAS RE-FILLED-ACY-0002
#    • 10-0071-00-3770 - ACETELYNE GAS RE-FILLED-ACY-0002
#    • 10-0071-00-3770 - ACETELYNE GAS RE-FILLED-ACY-0002
#
# 📦 ITEM GROUP 81 (1 items):
# --------------------------------------------------
#    • 10-0071-00-3771 - ACYTELENE CYLINDER-I110ACB
#
# 📦 ITEM GROUP 82 (1 items):
# --------------------------------------------------
#    • 10-0071-00-3780 - GAS, CARBON DIOXIDE (RE-FILL)-CO2-0001
#
# 📦 ITEM GROUP 83 (1 items):
# --------------------------------------------------
#    • 10-0071-00-3787 - OXYGEN CYLINDER-I110OXB
#
# 📦 ITEM GROUP 84 (3 items):
# --------------------------------------------------
#    • 10-0071-00-3788 - OXYGEN GAS RE-FILLED-OXY-0001
#    • 10-0071-00-3788 - OXYGEN GAS RE-FILLED-OXY-0001
#    • 10-0071-00-3788 - OXYGEN GAS RE-FILLED-OXY-0001
#
# 📦 ITEM GROUP 85 (1 items):
# --------------------------------------------------
#    • 10-0071-00-4944 - STEEL BRUSH-OM-0023
#
# 📦 ITEM GROUP 86 (1 items):
# --------------------------------------------------
#    • 10-0071-00-5500 - WINTER JACKET
#
# 📦 ITEM GROUP 87 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0046 - FIRE EXTINGUISHER POWDER REFILL 25KG-FEX-25KG
#
# 📦 ITEM GROUP 88 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0047 - FIRE EXTINGUISHER POWDER REFILL 4.5KG-FEX-4.5KG
#
# 📦 ITEM GROUP 89 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0048 - FIRE EXTINGUISHER POWDER "REFILL" 50KG-FEX-50KG
#
# 📦 ITEM GROUP 90 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0050 - FIRE EXTINGUISHER REFILL 10KG (POWDER)-FEXP-10KG
#
# 📦 ITEM GROUP 91 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0057 - FIRE EXTINGUISHER REFILL 6KG (POWDER)-FEXP-6KG
#
# 📦 ITEM GROUP 92 (1 items):
# --------------------------------------------------
#    • 10-0086-00-0077 - FIRE EXTINGUISHER "FOAM" REFILL 25LTR
#
# 📦 ITEM GROUP 93 (1 items):
# --------------------------------------------------
#    • 10-0151-00-0515 - BOLT 12MMX5CM
#
# 📦 ITEM GROUP 94 (1 items):
# --------------------------------------------------
#    • 10-0151-00-0862 - NUT 12MM
#
# 📦 ITEM GROUP 95 (1 items):
# --------------------------------------------------
#    • 10-0151-00-0901 - SCREW #14X1"
#
# 📦 ITEM GROUP 96 (1 items):
# --------------------------------------------------
#    • 10-0151-00-1061 - BOLT 12MMX3CM
#
# 📦 ITEM GROUP 97 (1 items):
# --------------------------------------------------
#    • 10-0156-00-0198 - HARDENER KAPCI 1-LTR-H-652
#
# 📦 ITEM GROUP 98 (1 items):
# --------------------------------------------------
#    • 10-0156-00-0801 - PAINT BLACK ENAMEL (OIL)
#
# 📦 ITEM GROUP 99 (1 items):
# --------------------------------------------------
#    • 10-0156-00-0927 - PAINT WHITE DYRUP
#
# 📦 ITEM GROUP 100 (1 items):
# --------------------------------------------------
#    • 10-0156-00-0955 - PAINT YELLOW CANARY
#
# 📦 ITEM GROUP 101 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0008 - CEMENT ORDINARY PORLAND-OPC-HBF-R(Y)DLD
#
# 📦 ITEM GROUP 102 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0028 - CEMENT ORDINARY PORLAND-OPC-RM-NAM(Y)DLD
#
# 📦 ITEM GROUP 103 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0032 - CEMENT ORDINARY PORLAND-MFC-OPC-RM-R(Y)DLD
#    • 10-0171-05-0032 - CEMENT ORDINARY PORLAND-MFC-OPC-RM-R(Y)DLD
#
# 📦 ITEM GROUP 104 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0035 - CEMENT ORDINARY PORLAND-OPC-RM-MAS(Y)DLD
#    • 10-0171-05-0035 - CEMENT ORDINARY PORLAND-OPC-RM-MAS(Y)DLD
#
# 📦 ITEM GROUP 105 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0039 - Cement Ordinary Porland-MFC-OPC-RM-R(Y)
#    • 10-0171-05-0039 - Cement Ordinary Porland-MFC-OPC-RM-R(Y)
#
# 📦 ITEM GROUP 106 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0040 - Cement Ordinary Porland-MFC-OPC-RM-MAS(Y)
#    • 10-0171-05-0040 - Cement Ordinary Porland-MFC-OPC-RM-MAS(Y)
#
# 📦 ITEM GROUP 107 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0042 - Cement Ordinary Porland-MFC-OPC-RM-S(Y)
#    • 10-0171-05-0042 - Cement Ordinary Porland-MFC-OPC-RM-S(Y)
#
# 📦 ITEM GROUP 108 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0045 - Cement Sulphate Resisting-MFC-SRC-RM-MAS(Y)
#    • 10-0171-05-0045 - Cement Sulphate Resisting-MFC-SRC-RM-MAS(Y)
#
# 📦 ITEM GROUP 109 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0048 - MICROSILICA EURPEAN -FR-MFC-212EUR001
#
# 📦 ITEM GROUP 110 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0052 - CEMENT SULPHATE RESISTING-SRC-RM-NAM(Y)DLD
#
# 📦 ITEM GROUP 111 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0053 - CEMENT SULPHATE RESISTING-SRC-RM-MAS(Y)DLD
#    • 10-0171-05-0053 - CEMENT SULPHATE RESISTING-SRC-RM-MAS(Y)DLD
#
# 📦 ITEM GROUP 112 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0054 - CEMENT SULPHATE RESISTING-MFC-SRC-RM-R(Y)DLD
#    • 10-0171-05-0054 - CEMENT SULPHATE RESISTING-MFC-SRC-RM-R(Y)DLD
#
# 📦 ITEM GROUP 113 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0056 - Cement Sulphate Resisting-MFC-SRC-RM-R(Y)
#    • 10-0171-05-0056 - Cement Sulphate Resisting-MFC-SRC-RM-R(Y)
#
# 📦 ITEM GROUP 114 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0057 - Cement Sulphate Resisting-MFC-SRC-RM-S(Y)
#    • 10-0171-05-0057 - Cement Sulphate Resisting-MFC-SRC-RM-S(Y)
#
# 📦 ITEM GROUP 115 (4 items):
# --------------------------------------------------
#    • 10-0171-05-0103 - CEMENT ORDINARY PORLAND (OPC-RM-HAMDAN-SOBHI)
#    • 10-0171-05-0103 - CEMENT ORDINARY PORLAND (OPC-RM-HAMDAN-SOBHI)
#    • 10-0171-05-0104 - CEMENT ORDINARY PORLAND (OPC-RM-HAMDAN-SOBHI) DLD
#    • 10-0171-05-0104 - CEMENT ORDINARY PORLAND (OPC-RM-HAMDAN-SOBHI) DLD
#
# 📦 ITEM GROUP 117 (4 items):
# --------------------------------------------------
#    • 10-0171-05-0105 - CEMENT SULPHATE RESISTING (SRC-RM-HAMDAN-SOBHI)
#    • 10-0171-05-0105 - CEMENT SULPHATE RESISTING (SRC-RM-HAMDAN-SOBHI)
#    • 10-0171-05-0106 - CEMENT SULPHATE RESISTING (SRC-RM-HAMDAN-SOBHI) DLD
#    • 10-0171-05-0106 - CEMENT SULPHATE RESISTING (SRC-RM-HAMDAN-SOBHI) DLD
#
# 📦 ITEM GROUP 119 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0129 - CEMENT SULPHATE RESISTING-SRC-RM-MASHED (QASSIM) DLD
#
# 📦 ITEM GROUP 120 (1 items):
# --------------------------------------------------
#    • 10-0171-05-0131 - CEMENT ORDINARY PORLAND OPC-RM-MASHED (QASSIM) DLD
#
# 📦 ITEM GROUP 121 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0133 - CEMENT SULPHATE RESISTING (SRC-RM)
#    • 10-0171-05-0133 - CEMENT SULPHATE RESISTING (SRC-RM)
#
# 📦 ITEM GROUP 122 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0135 - CEMENT SULPHATE RESISTING (SRC-RM-DLD)
#    • 10-0171-05-0135 - CEMENT SULPHATE RESISTING (SRC-RM-DLD)
#
# 📦 ITEM GROUP 123 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0137 - CEMENT ORDINARY PORLAND (OPC-RM)
#    • 10-0171-05-0137 - CEMENT ORDINARY PORLAND (OPC-RM)
#
# 📦 ITEM GROUP 124 (2 items):
# --------------------------------------------------
#    • 10-0171-05-0139 - CEMENT ORDINARY PORLAND (OPC-RM-DLD)
#    • 10-0171-05-0139 - CEMENT ORDINARY PORLAND (OPC-RM-DLD)
#
# 📦 ITEM GROUP 125 (1 items):
# --------------------------------------------------
#    • 10-0181-06-0139 - ROUND BAR 10MMX6MTR
#
# 📦 ITEM GROUP 126 (1 items):
# --------------------------------------------------
#    • 10-0181-06-0165 - ROUND BAR 6MMX6MTR
#
# 📦 ITEM GROUP 127 (1 items):
# --------------------------------------------------
#    • 10-0191-01-0067 - Helmet Safety (Blue)-OM-1270B
#
# 📦 ITEM GROUP 128 (1 items):
# --------------------------------------------------
#    • 10-0191-01-0141 - SAFETY HELMET WHITE 3M-189920092-W
#
# 📦 ITEM GROUP 129 (3 items):
# --------------------------------------------------
#    • 10-0191-01-0178 - SAFETY SHOES "WURTH"-OM-173
#    • 10-0191-01-0178 - SAFETY SHOES "WURTH"-OM-173
#    • 10-0191-01-0178 - SAFETY SHOES "WURTH"-OM-173
#
# 📦 ITEM GROUP 130 (1 items):
# --------------------------------------------------
#    • 10-0191-01-0606 - SAFETY HELMET YELLOW-100497
#
# 📦 ITEM GROUP 131 (2 items):
# --------------------------------------------------
#    • 10-0191-01-0657 - SAFETY SHOES "WURTH" SPECIAL
#    • 10-0191-01-0657 - SAFETY SHOES "WURTH" SPECIAL
#
# 📦 ITEM GROUP 132 (1 items):
# --------------------------------------------------
#    • 10-0191-01-0671 - UNIFORM PANT & SHIRT BLUE W/LOGO-OM-0091B
#
# 📦 ITEM GROUP 133 (1 items):
# --------------------------------------------------
#    • 10-0191-01-0754 - SHIRT UNIFORM
#
# 📦 ITEM GROUP 134 (1 items):
# --------------------------------------------------
#    • 10-0206-00-0045 - PAPER ROLL-OM-0195
#
# 📦 ITEM GROUP 135 (1 items):
# --------------------------------------------------
#    • 10-0206-00-0610 - INTERNAL MEMO PAD (BIG SIZE)-SH-27
#
# 📦 ITEM GROUP 136 (1 items):
# --------------------------------------------------
#    • 100440 - SPRING FOR SCREEN MESH
#
# 📦 ITEM GROUP 137 (1 items):
# --------------------------------------------------
#    • 100462-Z - MARS VALVE
#
# 📦 ITEM GROUP 138 (2 items):
# --------------------------------------------------
#    • 100464 - STRAINER
#    • 100465 - STRAINER
#
# 📦 ITEM GROUP 139 (2 items):
# --------------------------------------------------
#    • 100484 - CHECK VALVE
#    • 102575 - CHECK VALVE
#
# 📦 ITEM GROUP 140 (9 items):
# --------------------------------------------------
#    • 1010600006 - Hydraulic Filter
#    • 114H-75-08200 - FILTER HYDRAULIC
#    • 118H-60-03000 - FILTER HYDRAULIC
#    • 132-8876 - FILTER HYDRAULIC
#    • 1G8878 - FILTER HYDRAULIC
#    • 4120001954001 - Filter Hydraulic
#    • 4120004037001 - Filter Hydraulic
#    • 9624541001 - Filter Hydraulic
#    • YLX53J - HYDRAULIC FILTER
#
# 📦 ITEM GROUP 141 (1 items):
# --------------------------------------------------
#    • 101506-2 - BALL JOINT
#
# 📦 ITEM GROUP 142 (1 items):
# --------------------------------------------------
#    • 101507 - Pressure Switch
#
# 📦 ITEM GROUP 143 (1 items):
# --------------------------------------------------
#    • 101517 - BALL VALVE
#
# 📦 ITEM GROUP 144 (1 items):
# --------------------------------------------------
#    • 102471 - BEARING CAM FOLLOWER
#
# 📦 ITEM GROUP 145 (2 items):
# --------------------------------------------------
#    • 102529 - BUTTERFLY VALVE
#    • 106316 - BUTTERFLY VALVE
#
# 📦 ITEM GROUP 146 (1 items):
# --------------------------------------------------
#    • 102568 - REPAIR KIT VALVE 3-WAY
#
# 📦 ITEM GROUP 147 (1 items):
# --------------------------------------------------
#    • 102811-1 - LEVEL INDICATOR
#
# 📦 ITEM GROUP 148 (1 items):
# --------------------------------------------------
#    • 10282460 - SEALING-WASHER
#
# 📦 ITEM GROUP 149 (1 items):
# --------------------------------------------------
#    • 102987 - FUEL PUMP
#
# 📦 ITEM GROUP 150 (1 items):
# --------------------------------------------------
#    • 103106 - ACCUTATOR (SCALE POINTER)
#
# 📦 ITEM GROUP 151 (1 items):
# --------------------------------------------------
#    • 103119 - 3/4" SOLENOID VALVE
#
# 📦 ITEM GROUP 152 (1 items):
# --------------------------------------------------
#    • 103258 - NEEDLE VALVE
#
# 📦 ITEM GROUP 153 (1 items):
# --------------------------------------------------
#    • 103263 - ELECTRIC MOTOR
#
# 📦 ITEM GROUP 154 (1 items):
# --------------------------------------------------
#    • 103576 - SOLENOID VALVE
#
# 📦 ITEM GROUP 155 (1 items):
# --------------------------------------------------
#    • 104031 - Flowmeter
#
# 📦 ITEM GROUP 156 (1 items):
# --------------------------------------------------
#    • 104032 - FLOW METER
#
# 📦 ITEM GROUP 157 (3 items):
# --------------------------------------------------
#    • 104308-1 - GEARMOTOR
#    • 104313-1 - GEARMOTOR
#    • 105036-1 - GEARMOTOR
#
# 📦 ITEM GROUP 158 (1 items):
# --------------------------------------------------
#    • 104310-1 - GEAR MOTOR
#
# 📦 ITEM GROUP 159 (1 items):
# --------------------------------------------------
#    • 104749 - PRESSURE RELIEF VALVE
#
# 📦 ITEM GROUP 160 (1 items):
# --------------------------------------------------
#    • 104824 - 3-way valve
#
# 📦 ITEM GROUP 161 (1 items):
# --------------------------------------------------
#    • 105159-1 - GEAR MOTOR
#
# 📦 ITEM GROUP 162 (1 items):
# --------------------------------------------------
#    • 105996 - INFRARED TEMPPERATURE SENSOR
#
# 📦 ITEM GROUP 163 (1 items):
# --------------------------------------------------
#    • 106105 - OIL FILTER HEAVY
#
# 📦 ITEM GROUP 164 (1 items):
# --------------------------------------------------
#    • 106527 - Thermo couple dryer  ( 9234 )
#
# 📦 ITEM GROUP 165 (1 items):
# --------------------------------------------------
#    • 106582-2 - ACTUATOR
#
# 📦 ITEM GROUP 166 (1 items):
# --------------------------------------------------
#    • 106619 - INDUCTIVE SENSOR
#
# 📦 ITEM GROUP 167 (1 items):
# --------------------------------------------------
#    • 106712 - PROXIMITY SENSOR SWITCH
#
# 📦 ITEM GROUP 168 (1 items):
# --------------------------------------------------
#    • 106990-2 - MODULATING MOTOR
#
# 📦 ITEM GROUP 169 (1 items):
# --------------------------------------------------
#    • 107006 - OIL VALVE
#
# 📦 ITEM GROUP 170 (1 items):
# --------------------------------------------------
#    • 107183-1 - GEAR MOTOR
#
# 📦 ITEM GROUP 171 (1 items):
# --------------------------------------------------
#    • 1080X620X160-HI-MN - MOVABLE JAW PLATE -1080X620X160 (HI-MN)
#
# 📦 ITEM GROUP 172 (1 items):
# --------------------------------------------------
#    • 10W15 - BEARING (561354)
#
# 📦 ITEM GROUP 173 (1 items):
# --------------------------------------------------
#    • 10W16 - BEARING FOR CRUSHER (561306)
#
# 📦 ITEM GROUP 174 (1 items):
# --------------------------------------------------
#    • 11.00R20-DS - TIRE TUBELESS SMOOTH "DESTONE"
#
# 📦 ITEM GROUP 175 (4 items):
# --------------------------------------------------
#    • 11R22.5-GY - TIRE TUBELESS "GOODYEAR"
#    • 12R22.5-GY - TIRE TUBELESS "GOODYEAR"
#    • 12R22.5-GY - TIRE TUBELESS "GOODYEAR"
#    • 295/80R22.5-GY - TIRE TUBELESS "GOODYEAR"
#
# 📦 ITEM GROUP 176 (3 items):
# --------------------------------------------------
#    • 11R22.5-JI - TIRE TUBELESS "JINYU"
#    • 12R22.5-JI - TIRE TUBELESS "JINYU"
#    • 315/80R22.5-JI - TIRE TUBELESS "JINYU"
#
# 📦 ITEM GROUP 177 (1 items):
# --------------------------------------------------
#    • 12.00X20 - TIRE W/TUBE & FLAP
#
# 📦 ITEM GROUP 178 (2 items):
# --------------------------------------------------
#    • 12.00X20-JN - TIRE W/TUBE & FLAP "JINYU"
#    • 325/95R24-JI - TIRE W/TUBE FLAP "JINYU"
#
# 📦 ITEM GROUP 179 (1 items):
# --------------------------------------------------
#    • 12.00X20-MRF - TIRE W/TUBE & FLAP SLM "MRF"
#
# 📦 ITEM GROUP 180 (1 items):
# --------------------------------------------------
#    • 12.00X24-GC - TIRE W/TUBE FLAP "GOLDEN CROWN"
#
# 📦 ITEM GROUP 181 (1 items):
# --------------------------------------------------
#    • 12.00X24-KE - TIRE W/ TUBE & FLAP  "KELLY"
#
# 📦 ITEM GROUP 182 (1 items):
# --------------------------------------------------
#    • 12.00X24-WL - TIRE W/TUBE & FLAP "WEST LAKE" ALL STEEL TUBE TYPE (160X157KX20PLY)
#
# 📦 ITEM GROUP 183 (3 items):
# --------------------------------------------------
#    • 122648 - FUEL WATER SEPARATOR FILTER
#    • 4110001593002 - FILTER FUEL WATER SEPARATOR
#    • BF46122 - Fuel Water Separator
#
# 📦 ITEM GROUP 184 (1 items):
# --------------------------------------------------
#    • 1292404 - FILTER FUEL (FS19914)
#
# 📦 ITEM GROUP 185 (1 items):
# --------------------------------------------------
#    • 1296396 - Filter Oil Hydraulic
#
# 📦 ITEM GROUP 186 (1 items):
# --------------------------------------------------
#    • 13-16-030000 - STRAINER FILTER
#
# 📦 ITEM GROUP 187 (1 items):
# --------------------------------------------------
#    • 131004-00018C - BUSHING, CARBURIZING
#
# 📦 ITEM GROUP 188 (1 items):
# --------------------------------------------------
#    • 1343838 - STATOR F.PROGRESSIVE CAVITY PUMP
#
# 📦 ITEM GROUP 189 (1 items):
# --------------------------------------------------
#    • 13501006 - OXYGEN HOSE 30MTR
#
# 📦 ITEM GROUP 190 (11 items):
# --------------------------------------------------
#    • 15208-31U0B - FILTER OIL
#    • 2075488 - Filter Oil
#    • 237101 - FILTER OIL
#    • 4110000556209 - FILTER OIL
#    • 4110002354001 - FILTER OIL
#    • 5000483 - FILTER OIL
#    • 5000483 - FILTER OIL
#    • B7499 - Oil Filter
#    • LF701 - Oil Filter
#    • LF9070 - FILTER OIL
#    • YA00058283 - OIL FILTER
#
# 📦 ITEM GROUP 191 (1 items):
# --------------------------------------------------
#    • 15888724 - SEAL REAR
#
# 📦 ITEM GROUP 192 (1 items):
# --------------------------------------------------
#    • 16.00X24-DA - TIRE W/TUBE & FLAP "DARAVAN"
#
# 📦 ITEM GROUP 193 (1 items):
# --------------------------------------------------
#    • 16.9-28 - INNER TUBE
#
# 📦 ITEM GROUP 194 (2 items):
# --------------------------------------------------
#    • 16.9X28-DS - TIRE TUBELESS  "DEESTONE"
#    • 275/70R16-DS - Tire Tubeless "Deestone"
#
# 📦 ITEM GROUP 195 (3 items):
# --------------------------------------------------
#    • 16546-JR500 - Filter Air
#    • AF-1811 - FILTER AIR
#    • AF-421 - FILTER AIR
#
# 📦 ITEM GROUP 196 (1 items):
# --------------------------------------------------
#    • 16X110X200 - SPRING
#
# 📦 ITEM GROUP 197 (1 items):
# --------------------------------------------------
#    • 17.5R25- SE - Tire W/ Tube & Flap "Sedora"
#
# 📦 ITEM GROUP 198 (1 items):
# --------------------------------------------------
#    • 17.5X25-WL - Tire Tubeless "West Lake"
#
# 📦 ITEM GROUP 199 (1 items):
# --------------------------------------------------
#    • 175-60-27380 - Filter Hyd, 07063-01100+Pt539+P557380+07063-01100
#
# 📦 ITEM GROUP 200 (5 items):
# --------------------------------------------------
#    • 175/65R14-HK - TIRE TUBELESS "HANKOOK"
#    • 195/75R16-HK - TIRE TUBELESS "HANKOOK"
#    • 195R14-HK - Tire Tubeless "Hankook"
#    • 255/65R17-HK - TIRE TUBELESS "HANKOOK"
#    • 255/70R16-HK - TIRE TUBELESS "HANKOOK"
#
# 📦 ITEM GROUP 201 (4 items):
# --------------------------------------------------
#    • 185/70R15 - TIRE TUBELESS
#    • 215/75R17.5 - TIRE TUBELESS
#    • 315/80R22.5 - TIRE TUBELESS
#    • 385/65R22.5 - TIRE "TUBELESS"
#
# 📦 ITEM GROUP 202 (1 items):
# --------------------------------------------------
#    • 187002 - HOLDER CUTTING TOOL HT11
#
# 📦 ITEM GROUP 203 (1 items):
# --------------------------------------------------
#    • 1875 - Horn Clip (1x100pcs)
#
# 📦 ITEM GROUP 204 (1 items):
# --------------------------------------------------
#    • 195-13-13420 - FILTER
#
# 📦 ITEM GROUP 205 (1 items):
# --------------------------------------------------
#    • 195/65R15-SO - TIRE TUBELESS "SONAR"
#
# 📦 ITEM GROUP 206 (3 items):
# --------------------------------------------------
#    • 195R15-NX - TIRE TUBELESS "NEXEN"
#    • 205R16-NX - TIRE TUBELESS "NEXEN"
#    • 215/60R16-NX - Tire Tubeless Nexen
#
# 📦 ITEM GROUP 207 (1 items):
# --------------------------------------------------
#    • 1P4577 - Flange
#
# 📦 ITEM GROUP 208 (1 items):
# --------------------------------------------------
#    • 1R0749 - FILTER FUEL (FF-5319)(BF614)
#
# 📦 ITEM GROUP 209 (1 items):
# --------------------------------------------------
#    • 2000124 - POWER PACK 20LTR
#
# 📦 ITEM GROUP 210 (8 items):
# --------------------------------------------------
#    • 2043673 - Fuel Filter
#    • 4110000589001 - FUEL FILTER
#    • 4110002354002 - FILTER FUEL
#    • 4616544 - FUEL FILTER
#    • 60130-05-00055 - FUEL FILTER
#    • BF840 - FILTER FUEL
#    • D00-034-01 - FUEL FILTER
#    • FF-149 - FILTER FUEL
#
# 📦 ITEM GROUP 211 (1 items):
# --------------------------------------------------
#    • 2075482 - FILTER FUEL (FF5421) (2314101)
#
# 📦 ITEM GROUP 212 (1 items):
# --------------------------------------------------
#    • 2110454 - HYD FILETR KIT 500H
#
# 📦 ITEM GROUP 213 (1 items):
# --------------------------------------------------
#    • 2111170 - FILTER FUEL (FS10141)
#
# 📦 ITEM GROUP 214 (2 items):
# --------------------------------------------------
#    • 2111173 - FILTER WATER
#    • WF-2075 - FILTER WATER
#
# 📦 ITEM GROUP 215 (1 items):
# --------------------------------------------------
#    • 211INDHTC - FLY ASH TYPE -F "HITECH"
#
# 📦 ITEM GROUP 216 (1 items):
# --------------------------------------------------
#    • 2141040 - ENGINE FILTER KIT 500/1000H
#
# 📦 ITEM GROUP 217 (1 items):
# --------------------------------------------------
#    • 215/75R17.5-DS - Tire Tubeles "Deestone"
#
# 📦 ITEM GROUP 218 (6 items):
# --------------------------------------------------
#    • 2185460 - FILTER AIR INNER
#    • 47362227 - FILTER AIR INNER
#    • 81.08405-0017 - FILTER AIR INNER
#    • 81.08405-0017 - FILTER AIR INNER
#    • AF4874 - Filter Inner
#    • PA5529 - Filter Air Inner
#
# 📦 ITEM GROUP 219 (6 items):
# --------------------------------------------------
#    • 2185463 - FILTER AIR OUTER
#    • 47362223 - FILTER AIR OUTER
#    • 81.08405-0021 - FILTER AIR OUTER
#    • 81.08405-0021 - FILTER AIR OUTER
#    • A-4928 - FILTER AIR OUTER
#    • PA5528 - Filter Air Outer
#
# 📦 ITEM GROUP 220 (3 items):
# --------------------------------------------------
#    • 22-16-070006 - FILTER SUCTION
#    • 40-15-030000 - HYDRAULIC SUCTION FILTER
#    • 4648651 - FILTER SUCTION
#
# 📦 ITEM GROUP 221 (1 items):
# --------------------------------------------------
#    • 22328 - Bearing Screen {22328emw33c3+11}" Rhp "
#
# 📦 ITEM GROUP 222 (1 items):
# --------------------------------------------------
#    • 225/70R15-HK - TIRE TUBELESS "HAANKOOK"
#
# 📦 ITEM GROUP 223 (1 items):
# --------------------------------------------------
#    • 225/70R17-TR - TIRE TUBELESS "TRIANGLE"
#
# 📦 ITEM GROUP 224 (1 items):
# --------------------------------------------------
#    • 225609 - FILTER RETURN LINE
#
# 📦 ITEM GROUP 225 (2 items):
# --------------------------------------------------
#    • 2304176 - ENGINE HYD FILTER SERVICE KIT 500H
#    • 2958995 - ENGINE HYD FILTER SERVICE KIT 500H
#
# 📦 ITEM GROUP 226 (1 items):
# --------------------------------------------------
#    • 2304180 - ENGINE HYD FILTER SERVICE KIT 1000H
#
# 📦 ITEM GROUP 227 (1 items):
# --------------------------------------------------
#    • 2307678 - Filter Element Set
#
# 📦 ITEM GROUP 228 (1 items):
# --------------------------------------------------
#    • 234486 - OIL FILTER (LF-4054)
#
# 📦 ITEM GROUP 229 (1 items):
# --------------------------------------------------
#    • 235/75R17.5-TR - Tire Tubles "Triangle"
#
# 📦 ITEM GROUP 230 (3 items):
# --------------------------------------------------
#    • 24060 - BEARING
#    • UCT-310 - BEARING
#    • UCT-312 - BEARING
#
# 📦 ITEM GROUP 231 (1 items):
# --------------------------------------------------
#    • 245/70R17-NX - TIRE TUBLESS "NEXEN"
#
# 📦 ITEM GROUP 232 (2 items):
# --------------------------------------------------
#    • 2450196 - ENGINE HYD FILTER SERVICE KIT 500H
#    • 2561734 - ENGINE HYD FILTER SERVICE KIT 500H
#
# 📦 ITEM GROUP 233 (1 items):
# --------------------------------------------------
#    • 248282 - VARIABLE MOTOR
#
# 📦 ITEM GROUP 234 (1 items):
# --------------------------------------------------
#    • 2642523 - CUTTING TOOLS W6 (19MM) 2069412/K6MW-1949-6866
#
# 📦 ITEM GROUP 235 (1 items):
# --------------------------------------------------
#    • 2682808 - TOOL HOLDER HT22+
#
# 📦 ITEM GROUP 236 (1 items):
# --------------------------------------------------
#    • 2721944 - ENGINE FILTER KIT 500/1000H
#
# 📦 ITEM GROUP 237 (3 items):
# --------------------------------------------------
#    • 29100000061 - Filter Oil Return
#    • 45-15-07000A - FILTER HYDRAULIC RETURN
#    • YLX50H - HYDRAULIC RETURN OIL FILTER
#
# 📦 ITEM GROUP 238 (1 items):
# --------------------------------------------------
#    • 295/80R22.5-JI - Tire Tubelles "Jinyu"
#
# 📦 ITEM GROUP 239 (1 items):
# --------------------------------------------------
#    • 3002629 - BLOW BAR
#
# 📦 ITEM GROUP 240 (4 items):
# --------------------------------------------------
#    • 315/80R22.5-KE - TIRE TUBELESS "KELLY"
#    • 315/80R22.5-KE - TIRE TUBELESS "KELLY"
#    • 385/65R22.5-KE - TIRE TUBELESS "KELLY"
#    • 385/65R22.5-KE - TIRE TUBELESS "KELLY"
#
# 📦 ITEM GROUP 241 (1 items):
# --------------------------------------------------
#    • 32/925683 - FILTER AIR ELEMENT PQ400
#
# 📦 ITEM GROUP 242 (1 items):
# --------------------------------------------------
#    • 32208J2 - Bearing
#
# 📦 ITEM GROUP 243 (2 items):
# --------------------------------------------------
#    • 325/95R24-MRF - TIRE W/TUBE & FLAP "MRF"
#    • 325/95R24-MRF - TIRE W/TUBE & FLAP "MRF"
#
# 📦 ITEM GROUP 244 (1 items):
# --------------------------------------------------
#    • 326-1643 - Water Seperator Filter
#
# 📦 ITEM GROUP 245 (1 items):
# --------------------------------------------------
#    • 3482081231 - PRESSURE PLATE
#
# 📦 ITEM GROUP 246 (2 items):
# --------------------------------------------------
#    • 372283 - FILTER PILOT
#    • 4630525 - PILOT FILTER
#
# 📦 ITEM GROUP 247 (1 items):
# --------------------------------------------------
#    • 386683 - CHUCK CLAMPING / BREAKING DEVICE
#
# 📦 ITEM GROUP 248 (1 items):
# --------------------------------------------------
#    • 39733 - GROOVED RING
#
# 📦 ITEM GROUP 250 (1 items):
# --------------------------------------------------
#    • 4110000076368 - Filter Trans
#
# 📦 ITEM GROUP 251 (1 items):
# --------------------------------------------------
#    • 4110000589016 - Filter Air Outer+Inner
#
# 📦 ITEM GROUP 252 (1 items):
# --------------------------------------------------
#    • 4110000763002 - Filter Air Inner P838813
#
# 📦 ITEM GROUP 253 (2 items):
# --------------------------------------------------
#    • 4110001016004 - FUEL SEPERATOR FILTER
#    • 5234987 - FILTER FUEL SEPERATOR
#
# 📦 ITEM GROUP 254 (1 items):
# --------------------------------------------------
#    • 4120004036003 - Filter Oil Brake
#
# 📦 ITEM GROUP 255 (1 items):
# --------------------------------------------------
#    • 4437838 - AIR BREATHER FILTER
#
# 📦 ITEM GROUP 257 (1 items):
# --------------------------------------------------
#    • 4616545 - FUEL MAIN FILTER
#
# 📦 ITEM GROUP 258 (1 items):
# --------------------------------------------------
#    • 495X105X100-MN - GRINDING RAIL -495X105X100 (MN)
#
# 📦 ITEM GROUP 259 (1 items):
# --------------------------------------------------
#    • 496-9842 - STANDARD EFFICIENCY ENGINE AIR - SECONDARY
#
# 📦 ITEM GROUP 260 (1 items):
# --------------------------------------------------
#    • 504127326 - ENGINE SEAL FRONT
#
# 📦 ITEM GROUP 261 (1 items):
# --------------------------------------------------
#    • 504127327 - ENGINE SEAL REAR
#
# 📦 ITEM GROUP 262 (1 items):
# --------------------------------------------------
#    • 504128021 - GASKET
#
# 📦 ITEM GROUP 263 (1 items):
# --------------------------------------------------
#    • 51.06402-0064 - THERMOSTAT
#
# 📦 ITEM GROUP 264 (1 items):
# --------------------------------------------------
#    • 51.06601-0275 - Suction Fan
#
# 📦 ITEM GROUP 265 (1 items):
# --------------------------------------------------
#    • 51.95800-6099 - BELT TENSIONER PULLEY
#
# 📦 ITEM GROUP 266 (1 items):
# --------------------------------------------------
#    • 510126-2 - VALVE ASSY
#
# 📦 ITEM GROUP 267 (1 items):
# --------------------------------------------------
#    • 510152-1 - ACTUATED VALVE ASSEMBLY 3-WAY
#
# 📦 ITEM GROUP 268 (1 items):
# --------------------------------------------------
#    • 510311 - SEAL KIT FOR HOT OIL PUMP
#
# 📦 ITEM GROUP 269 (1 items):
# --------------------------------------------------
#    • 510315-1 - TRUNIOUN RING C/W MOUNTING 2X
#
# 📦 ITEM GROUP 270 (2 items):
# --------------------------------------------------
#    • 510350-1 - HOT OIL PUMP
#    • 510584 - HOT OIL PUMP
#
# 📦 ITEM GROUP 271 (1 items):
# --------------------------------------------------
#    • 510387-4 - TRUNIOUN ROLLER C/W SHAFT
#
# 📦 ITEM GROUP 272 (1 items):
# --------------------------------------------------
#    • 510423 - BUTTERFLY VALVE ASSEMBLY
#
# 📦 ITEM GROUP 273 (1 items):
# --------------------------------------------------
#    • 510429 - THRUST ROLLER ASSEMBLY
#
# 📦 ITEM GROUP 274 (1 items):
# --------------------------------------------------
#    • 510430-08 - BALL JOINT
#
# 📦 ITEM GROUP 276 (1 items):
# --------------------------------------------------
#    • 510498-1 - ACTUATED VALVE ASSEMBLY 6"
#
# 📦 ITEM GROUP 277 (1 items):
# --------------------------------------------------
#    • 510499 - BUTTERFLY VALE ASSY
#
# 📦 ITEM GROUP 278 (1 items):
# --------------------------------------------------
#    • 510546-1 - RELIEF VALVE
#
# 📦 ITEM GROUP 279 (1 items):
# --------------------------------------------------
#    • 510628-1 - ACTUATED VALVE ASSEMBLY 4"
#
# 📦 ITEM GROUP 280 (1 items):
# --------------------------------------------------
#    • 510766 - TRUNNION ROLLER C/W SHAFT
#
# 📦 ITEM GROUP 281 (2 items):
# --------------------------------------------------
#    • 510X350X130-CR - BLOW BAR SPANISH-510X350X130 (CR)
#    • 510X350X130-CR - BLOW BAR SPANISH-510X350X130 (CR)
#
# 📦 ITEM GROUP 282 (1 items):
# --------------------------------------------------
#    • 525746 - O-RING
#
# 📦 ITEM GROUP 283 (1 items):
# --------------------------------------------------
#    • 5505131 - PTO POWER TAKE OFF
#
# 📦 ITEM GROUP 284 (2 items):
# --------------------------------------------------
#    • 567820 - PRESSURE RING
#    • 568130 - PRESSURE RING
#
# 📦 ITEM GROUP 285 (1 items):
# --------------------------------------------------
#    • 567826 - BEARING BUSHING
#
# 📦 ITEM GROUP 286 (1 items):
# --------------------------------------------------
#    • 567931 - SHANK ADAPTER
#
# 📦 ITEM GROUP 287 (1 items):
# --------------------------------------------------
#    • 570396 - BALANCE ROD
#
# 📦 ITEM GROUP 288 (1 items):
# --------------------------------------------------
#    • 571007 - FLUSHING SWIVEL D110/LL
#
# 📦 ITEM GROUP 289 (1 items):
# --------------------------------------------------
#    • 571426 - FLUSHING SHAFT
#
# 📦 ITEM GROUP 290 (1 items):
# --------------------------------------------------
#    • 571427 - FUSHING HEAD LL/D110 AT KD 1215R
#
# 📦 ITEM GROUP 291 (1 items):
# --------------------------------------------------
#    • 574376 - BALANCED ROD
#
# 📦 ITEM GROUP 292 (1 items):
# --------------------------------------------------
#    • 590832 - WIPER
#
# 📦 ITEM GROUP 293 (1 items):
# --------------------------------------------------
#    • 5909787 - FILTER HYDRAULIC ELEMENT (4888581)
#
# 📦 ITEM GROUP 294 (1 items):
# --------------------------------------------------
#    • 61006405 - BASE
#
# 📦 ITEM GROUP 295 (1 items):
# --------------------------------------------------
#    • 612600061936 - WATER LINE
#
# 📦 ITEM GROUP 296 (1 items):
# --------------------------------------------------
#    • 612600070299 - OIL PUMP ASSEMBLY
#
# 📦 ITEM GROUP 297 (1 items):
# --------------------------------------------------
#    • 612601110925 - TURBO CHARGER
#
# 📦 ITEM GROUP 298 (2 items):
# --------------------------------------------------
#    • 6150-61-1520J - Seal
#    • 98429617 - SEAL
#
# 📦 ITEM GROUP 299 (1 items):
# --------------------------------------------------
#    • 6151-K6-9901J - Gasket Kit
#
# 📦 ITEM GROUP 300 (1 items):
# --------------------------------------------------
#    • 7.00X16-RO - TIRE TUBELESS "ROADX"
#
# 📦 ITEM GROUP 301 (1 items):
# --------------------------------------------------
#    • 70-15-050000 - BREATHER FILTER
#
# 📦 ITEM GROUP 302 (1 items):
# --------------------------------------------------
#    • 7000008 - PATTERN CHARGES
#
# 📦 ITEM GROUP 303 (1 items):
# --------------------------------------------------
#    • 750616010011 - DRILL BIT D76-T45
#
# 📦 ITEM GROUP 304 (1 items):
# --------------------------------------------------
#    • 750712010472 - DRILL ROD T45X3.66 (MF)SPEED TYPE
#
# 📦 ITEM GROUP 305 (1 items):
# --------------------------------------------------
#    • 795800 - ROUND SHANK CHISEL (BK47)
#
# 📦 ITEM GROUP 306 (1 items):
# --------------------------------------------------
#    • 8.25X16-DS - TIRE W/TUBE & FLAP 'DEESTONE'
#
# 📦 ITEM GROUP 307 (1 items):
# --------------------------------------------------
#    • 81.01810-6012 - Oil Filter Pipe
#
# 📦 ITEM GROUP 308 (1 items):
# --------------------------------------------------
#    • 81.06620-0134 - FAN COVER
#
# 📦 ITEM GROUP 309 (1 items):
# --------------------------------------------------
#    • 81.06620-0187 - FAN COWL
#
# 📦 ITEM GROUP 310 (1 items):
# --------------------------------------------------
#    • 81.52151-6098 - AIR VALVE
#
# 📦 ITEM GROUP 311 (1 items):
# --------------------------------------------------
#    • 81.61910-0045 - FILTER A/C
#
# 📦 ITEM GROUP 312 (1 items):
# --------------------------------------------------
#    • 81.74821-0095 - SHOCK ABSORBER(GAS SPRING HOOD)
#
# 📦 ITEM GROUP 313 (1 items):
# --------------------------------------------------
#    • 81.96301-0668 - HOSE INTER COOLER
#
# 📦 ITEM GROUP 314 (1 items):
# --------------------------------------------------
#    • 8200335 - AIR FILTER
#
# 📦 ITEM GROUP 315 (1 items):
# --------------------------------------------------
#    • 8314012 - FITTING HOSE 12MM
#
# 📦 ITEM GROUP 316 (1 items):
# --------------------------------------------------
#    • 83701566 - TRACK PAD KIT 53PCS/KIT (BF800)
#
# 📦 ITEM GROUP 317 (1 items):
# --------------------------------------------------
#    • 85.96020-0004 - RUBBER BUSHING
#
# 📦 ITEM GROUP 318 (1 items):
# --------------------------------------------------
#    • 880X640X170-HI-MN - FIXED JAW PLATE -880X640X170 (HI-MN)
#
# 📦 ITEM GROUP 319 (1 items):
# --------------------------------------------------
#    • 9180-B091-102 - Oil Lance Assembly
#
# 📦 ITEM GROUP 320 (1 items):
# --------------------------------------------------
#    • 9234-B091-508 - OIL RECEIVER TANK
#
# 📦 ITEM GROUP 321 (1 items):
# --------------------------------------------------
#    • 9255-B371-401 - FASTENER KIT FOR LINER & SEAL
#
# 📦 ITEM GROUP 322 (2 items):
# --------------------------------------------------
#    • 9255-B431-203 - BH HEAD SEAL BLOCK ASSY
#    • 9255-B435-104 - HEAD SEAL BLOCK ASSY
#
# 📦 ITEM GROUP 323 (2 items):
# --------------------------------------------------
#    • 9255-B431-204 - BH TAIL SEAL BLOCK ASSY
#    • 9255-B435-105 - TAIL SEAL BLOCK ASSY
#
# 📦 ITEM GROUP 326 (1 items):
# --------------------------------------------------
#    • 9255-B435-204 - DUST CONDITIONER HEAD SEAL BLOCK ASSY
#
# 📦 ITEM GROUP 327 (1 items):
# --------------------------------------------------
#    • 9255-B435-207 - DUST CONDITIONER TAIL SEAL SEAL BLOCK ASSY
#
# 📦 ITEM GROUP 328 (1 items):
# --------------------------------------------------
#    • 9624531001 - FILTER HYDRAULIC ELEMENT
#
# 📦 ITEM GROUP 329 (3 items):
# --------------------------------------------------
#    • 98400781 - GASKET
#    • 98418138 - GASKET
#    • 98424046 - GASKET
#
# 📦 ITEM GROUP 330 (1 items):
# --------------------------------------------------
#    • 98482590 - GASKET,ENGINE
#
# 📦 ITEM GROUP 331 (1 items):
# --------------------------------------------------
#    • AC-273-614C - BOLT 25X40
#
# 📦 ITEM GROUP 332 (1 items):
# --------------------------------------------------
#    • ACE-44/200 - ENCLOSURE W/PLATE
#
# 📦 ITEM GROUP 333 (1 items):
# --------------------------------------------------
#    • AES-1411 - IGNITION SWITCH
#
# 📦 ITEM GROUP 334 (1 items):
# --------------------------------------------------
#    • AF-1862M - FILTER AIR OUTER (PA2577)(P13-4353)
#
# 📦 ITEM GROUP 335 (1 items):
# --------------------------------------------------
#    • AF-1863M - FILTER AIR INNER (PA2578)
#
# 📦 ITEM GROUP 336 (1 items):
# --------------------------------------------------
#    • AF-4609 - Filter Air Outer(8n6309)(Pa2653)
#
# 📦 ITEM GROUP 337 (1 items):
# --------------------------------------------------
#    • AF-4842 - FILTER AIR(P77-1595,C331015)
#
# 📦 ITEM GROUP 338 (1 items):
# --------------------------------------------------
#    • AF-851M - Filter Air Outer(Pa1894)
#
# 📦 ITEM GROUP 339 (1 items):
# --------------------------------------------------
#    • AF-872 - FILTER AIR (PA2333)
#
# 📦 ITEM GROUP 340 (1 items):
# --------------------------------------------------
#    • AF26439 - FILTER AIR OUTER (2474-9051)(PA30109)
#
# 📦 ITEM GROUP 342 (1 items):
# --------------------------------------------------
#    • B-272-318C - ROTARY SEALING (48S)
#
# 📦 ITEM GROUP 343 (1 items):
# --------------------------------------------------
#    • B-273-731C - JAW PLATE
#
# 📦 ITEM GROUP 344 (1 items):
# --------------------------------------------------
#    • B-273-788/C - Die Jaw Stationary
#
# 📦 ITEM GROUP 345 (1 items):
# --------------------------------------------------
#    • B006700770010 - FILTER, OIL SEPERATOR
#
# 📦 ITEM GROUP 346 (1 items):
# --------------------------------------------------
#    • B2 - FILTER OIL (LF-551A)
#
# 📦 ITEM GROUP 347 (1 items):
# --------------------------------------------------
#    • B374-23 - Mixer Paddle Tip - 0300948
#
# 📦 ITEM GROUP 348 (1 items):
# --------------------------------------------------
#    • B374-24 - Mixer End Paddle Tip 0300949
#
# 📦 ITEM GROUP 349 (1 items):
# --------------------------------------------------
#    • B374-84 - PADDLE ARM CLAMP
#
# 📦 ITEM GROUP 351 (1 items):
# --------------------------------------------------
#    • BT427 - FILTER OIL (W940/34)(LF3345)
#
# 📦 ITEM GROUP 352 (1 items):
# --------------------------------------------------
#    • C-273-623C - BOLT 1.5"
#
# 📦 ITEM GROUP 353 (1 items):
# --------------------------------------------------
#    • C271250/1 - FILTER AIR OUTER (81.008405-0021) MF-00529S
#
# 📦 ITEM GROUP 354 (1 items):
# --------------------------------------------------
#    • C2874334 - RADIATOR COOLING FAN
#
# 📦 ITEM GROUP 355 (1 items):
# --------------------------------------------------
#    • C5656323 - DATA PLATE
#
# 📦 ITEM GROUP 356 (1 items):
# --------------------------------------------------
#    • CB-305 - CARBON BRUSH 2PCS=1PAIR
#
# 📦 ITEM GROUP 357 (1 items):
# --------------------------------------------------
#    • CH-H-8/16 - Hook, Chain
#
# 📦 ITEM GROUP 358 (1 items):
# --------------------------------------------------
#    • CHC1210IP - IMPACT PLATE PF1210V, 34X17X10.5 (PE1210)
#
# 📦 ITEM GROUP 359 (1 items):
# --------------------------------------------------
#    • CHC1214IP - Impact Plate Pf1214/1212v (33cm)
#
# 📦 ITEM GROUP 360 (1 items):
# --------------------------------------------------
#    • CHC1315IP - IMPACT PLATE FOR 1315FP
#
# 📦 ITEM GROUP 361 (1 items):
# --------------------------------------------------
#    • CHL-16MM - Chain Link
#
# 📦 ITEM GROUP 362 (1 items):
# --------------------------------------------------
#    • CHS4.25OLS - OIL LUBRICATION STATION FOR SYMONS CRUSHER
#
# 📦 ITEM GROUP 363 (2 items):
# --------------------------------------------------
#    • CL-8/16-inch - Connecting Link
#    • CL-LI-8-16MM - Connecting Link
#
# 📦 ITEM GROUP 364 (4 items):
# --------------------------------------------------
#    • CRU-AGG0005-MED - AGGREGATE 3/4"
#    • CRU-AGG0005-MED - AGGREGATE 3/4"
#    • CRU-AGG0005-MED - AGGREGATE 3/4"
#    • CRU-AGG0005-MED - AGGREGATE 3/4"
#
# 📦 ITEM GROUP 365 (1 items):
# --------------------------------------------------
#    • CRU-AGG0007-MED - AGGREGATE 3/8"
#
# 📦 ITEM GROUP 366 (2 items):
# --------------------------------------------------
#    • D81151 - Rubber Plug
#    • D81151 - Rubber Plug
#
# 📦 ITEM GROUP 367 (1 items):
# --------------------------------------------------
#    • DF-841302 - FUEL WATER SEPARATOR
#
# 📦 ITEM GROUP 368 (1 items):
# --------------------------------------------------
#    • DSE890MKII - GATEWAY,REMOTE MONITORING
#
# 📦 ITEM GROUP 369 (1 items):
# --------------------------------------------------
#    • DZ13241845013 - Compressor A/C
#
# 📦 ITEM GROUP 370 (1 items):
# --------------------------------------------------
#    • E-CT-1/4" - Copper Tube(Pipe)1/4"
#
# 📦 ITEM GROUP 371 (1 items):
# --------------------------------------------------
#    • E-CT-5/8" - COPPER PIPE 5/8"
#
# 📦 ITEM GROUP 372 (1 items):
# --------------------------------------------------
#    • EM-22KW - ELECTRIC MOTOR 22KW, 30HP, 380V, 60Hz, RPM 1400-1750
#
# 📦 ITEM GROUP 373 (1 items):
# --------------------------------------------------
#    • FF-5054 - Filter Fuel
#
# 📦 ITEM GROUP 374 (1 items):
# --------------------------------------------------
#    • FF-5323 - FILTER FUEL ELEMENT (FF-5337/1R0743,1R0756)
#
# 📦 ITEM GROUP 375 (2 items):
# --------------------------------------------------
#    • FF5018 - FILTER FUEL  (BF988)(WK-731)(SP-974M)
#    • FF5018 - FILTER FUEL  (BF988)(WK-731)(SP-974M)
#
# 📦 ITEM GROUP 376 (1 items):
# --------------------------------------------------
#    • FF5702 - FILTER FUEL (P55-0372) (BF7997) (WK962/7)
#
# 📦 ITEM GROUP 377 (1 items):
# --------------------------------------------------
#    • FL-P-H12 - FLANGE PATTERN
#
# 📦 ITEM GROUP 378 (1 items):
# --------------------------------------------------
#    • FS-1095 - FILTER FUEL (BF46122)
#
# 📦 ITEM GROUP 379 (1 items):
# --------------------------------------------------
#    • FS1006 - FILTER FUEL (600-311-3110, 600-311-3111)
#
# 📦 ITEM GROUP 380 (2 items):
# --------------------------------------------------
#    • FS1212 - FILTER DIESEL (BF1212)
#    • FS1212 - FILTER DIESEL (BF1212)
#
# 📦 ITEM GROUP 381 (1 items):
# --------------------------------------------------
#    • FS19811 - Fuel Filter Fs19530 (P55-1429)
#
# 📦 ITEM GROUP 382 (1 items):
# --------------------------------------------------
#    • FS19975 - FUEL WATER SEPARATOR (BF7950D)
#
# 📦 ITEM GROUP 383 (26 items):
# --------------------------------------------------
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#    • FUEL-D1 - DIESEL
#
# 📦 ITEM GROUP 384 (6 items):
# --------------------------------------------------
#    • FUEL-G91 - GASOLINE91
#    • FUEL-G91 - GASOLINE91
#    • FUEL-G91 - GASOLINE91
#    • FUEL-G91 - GASOLINE91
#    • FUEL-G91 - GASOLINE91
#    • FUEL-G91 - GASOLINE91
#
# 📦 ITEM GROUP 385 (1 items):
# --------------------------------------------------
#    • H-MOTOR-YE3-250-4 - HYDRAULIC MOTOR FOR TRACK -YE3-250M-4
#
# 📦 ITEM GROUP 386 (1 items):
# --------------------------------------------------
#    • H2-272-310 - Inner Sleeve
#
# 📦 ITEM GROUP 387 (1 items):
# --------------------------------------------------
#    • HDX-630X10Q - FILTER,HYDRAULIC
#
# 📦 ITEM GROUP 388 (1 items):
# --------------------------------------------------
#    • HF29076 - FILTER HYDRAULIC (BT9454)
#
# 📦 ITEM GROUP 389 (2 items):
# --------------------------------------------------
#    • HF6356 - FILTER HYDRAULIC ELEMENT (PT-397)(P55-1142)
#    • HF6356 - FILTER HYDRAULIC ELEMENT (PT-397)(P55-1142)
#
# 📦 ITEM GROUP 390 (1 items):
# --------------------------------------------------
#    • IND76MM-T45 - BUTTON BIT T45 76MM (SANDVIK)
#
# 📦 ITEM GROUP 391 (1 items):
# --------------------------------------------------
#    • IP-1045-320-140 - IMPACT HAMMER (1045mm x320mm x140mm)
#
# 📦 ITEM GROUP 392 (1 items):
# --------------------------------------------------
#    • J213-84C-011000 - FILTER PILOT LINE
#
# 📦 ITEM GROUP 393 (1 items):
# --------------------------------------------------
#    • K2640Z - AIR FILTER KIT
#
# 📦 ITEM GROUP 394 (1 items):
# --------------------------------------------------
#    • LF-3485 - FILTER OIL (P55-7500,7N7500)
#
# 📦 ITEM GROUP 395 (1 items):
# --------------------------------------------------
#    • LF16015 - OIL FILTER (84228488)(BT7237)
#
# 📦 ITEM GROUP 396 (1 items):
# --------------------------------------------------
#    • LF16173 - FILTER OIL (LF16173)
#
# 📦 ITEM GROUP 397 (1 items):
# --------------------------------------------------
#    • LF17556 - FILTER  OIL PQ44X10 (B7350)
#
# 📦 ITEM GROUP 398 (1 items):
# --------------------------------------------------
#    • LF3349 - OIL FILTER (BT339)(P55-8616)
#
# 📦 ITEM GROUP 399 (1 items):
# --------------------------------------------------
#    • LF670 - FILTER OIL (B96)(P55-1670)
#
# 📦 ITEM GROUP 400 (2 items):
# --------------------------------------------------
#    • LF9009 - FILTER OIL (BD7309) (P55-3000)
#    • LF9009 - FILTER OIL (BD7309) (P55-3000)
#
# 📦 ITEM GROUP 401 (1 items):
# --------------------------------------------------
#    • ME4-DRV1.1 - ELECTRONIC CARD FOR CRUSHER INVERTER ME4-DRV1.1 2020.06.02
#
# 📦 ITEM GROUP 402 (1 items):
# --------------------------------------------------
#    • MF55D23L-AL - BATTERY "ALPHA" MF55D23L
#
# 📦 ITEM GROUP 403 (1 items):
# --------------------------------------------------
#    • MF80D26L-AC - BATTERY 80D26L-MF 12V "AC DELCO"
#
# 📦 ITEM GROUP 404 (1 items):
# --------------------------------------------------
#    • MF80D26L-KK - BATTERY 80D26L-MF 12V "KRANK"
#
# 📦 ITEM GROUP 405 (1 items):
# --------------------------------------------------
#    • MF80D26L-NT - BATTERY 80D26L-MF 12V (70AMP) "NITRO"
#
# 📦 ITEM GROUP 406 (1 items):
# --------------------------------------------------
#    • MFC-212EUR001 - MICROSILICA EURPEAN -FR
#
# 📦 ITEM GROUP 407 (1 items):
# --------------------------------------------------
#    • MFC-OPC-RM-MAS(Y) - CEMENT ORDINARY PORLAND
#
# 📦 ITEM GROUP 408 (1 items):
# --------------------------------------------------
#    • MFC-SRC-RM-MAS(Y) - CEMENT SULPHATE RESISTING
#
# 📦 ITEM GROUP 409 (6 items):
# --------------------------------------------------
#    • MSWP-0001-MED - RAW SAND
#    • MSWP-0001-MED - RAW SAND
#    • MSWP-0001-MED - RAW SAND
#    • MSWP-0001-MED - RAW SAND
#    • MSWP-0001-MED - RAW SAND
#    • MSWP-0001-MED - RAW SAND
#
# 📦 ITEM GROUP 410 (6 items):
# --------------------------------------------------
#    • MSWP-0002-MED - DUNE SAND
#    • MSWP-0002-MED - DUNE SAND
#    • MSWP-0002-MED - DUNE SAND
#    • MSWP-0002-MED - DUNE SAND
#    • MSWP-0002-MED - DUNE SAND
#    • MSWP-0002-MED - DUNE SAND
#
# 📦 ITEM GROUP 411 (7 items):
# --------------------------------------------------
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#    • MSWP-0004-MED - DOUBLE WASHED SAND
#
# 📦 ITEM GROUP 412 (1 items):
# --------------------------------------------------
#    • N-150-HK - Battery 150amp (Hankook)
#
# 📦 ITEM GROUP 413 (1 items):
# --------------------------------------------------
#    • N-170-SU - BATTERY, AUTO-12V/170AMP "SUPER"
#
# 📦 ITEM GROUP 414 (1 items):
# --------------------------------------------------
#    • N-70-AC - BATTERY AC DELCO 70AMP,12V
#
# 📦 ITEM GROUP 415 (1 items):
# --------------------------------------------------
#    • OM-176-WU - Safety Shoes Hi-Cut (Wurth)
#
# 📦 ITEM GROUP 416 (1 items):
# --------------------------------------------------
#    • P7017 - FILTER OIL (LF-756) (W932/2)  (AF-274/4X)
#
# 📦 ITEM GROUP 417 (1 items):
# --------------------------------------------------
#    • P7321 - FILTER OIL(CH-10929)
#
# 📦 ITEM GROUP 418 (1 items):
# --------------------------------------------------
#    • PA1885 - FILTER AIR OUTER(AF-1905M)(600-181-4311)
#
# 📦 ITEM GROUP 419 (1 items):
# --------------------------------------------------
#    • PA1893 - FILTER AIR INNER (AF-1904M)
#
# 📦 ITEM GROUP 420 (1 items):
# --------------------------------------------------
#    • PA2547 - AIR FILTER INNER (11N6-20620)(P14-1319)
#
# 📦 ITEM GROUP 421 (1 items):
# --------------------------------------------------
#    • PA2577 - FILTER AIR OUTER SFA31309 (P13-4353,AF-1862M)
#
# 📦 ITEM GROUP 422 (1 items):
# --------------------------------------------------
#    • PA30108 - Filter Air Inner (2474-9057)
#
# 📦 ITEM GROUP 423 (1 items):
# --------------------------------------------------
#    • PA5467 - AIR FILTER OUTER (AF25910)
#
# 📦 ITEM GROUP 424 (1 items):
# --------------------------------------------------
#    • PF-1210/S - Blow Bar 4Pcs/Set 1210C3 (Pf1210C3-Cr26)
#
# 📦 ITEM GROUP 425 (1 items):
# --------------------------------------------------
#    • PF1214-V - Lock For Blow Bar Pf12114/1210/1212
#
# 📦 ITEM GROUP 426 (1 items):
# --------------------------------------------------
#    • PT-CN24HXXA30BAN - POWER PACK UNIT 40 LTR
#
# 📦 ITEM GROUP 427 (1 items):
# --------------------------------------------------
#    • QT-0001400 - AUTO LAMP 24V
#
# 📦 ITEM GROUP 428 (1 items):
# --------------------------------------------------
#    • RS3513 - FILTER AIR INNER (612508)
#
# 📦 ITEM GROUP 429 (1 items):
# --------------------------------------------------
#    • RS3870 - FILTER AIR OUTER (AF25454)(P77-7868)
#
# 📦 ITEM GROUP 430 (1 items):
# --------------------------------------------------
#    • RS3988 - Filter Air Outer(P82-2768)(2310167)
#
# 📦 ITEM GROUP 431 (1 items):
# --------------------------------------------------
#    • RS3993 - FILTER AIR INNER (CF500)
#
# 📦 ITEM GROUP 432 (1 items):
# --------------------------------------------------
#    • RS5748 - AIR FILTER INNER (AF27999)
#
# 📦 ITEM GROUP 433 (1 items):
# --------------------------------------------------
#    • SE-196 - CLEARANCE LIGHT 'LED'
#
# 📦 ITEM GROUP 434 (1 items):
# --------------------------------------------------
#    • SH-SYM-5.5-001 - CONCAVE SH 5.5" SYMONS
#
# 📦 ITEM GROUP 435 (1 items):
# --------------------------------------------------
#    • SH-SYM-5.5-002 - MANTLE SH 5.5" SYMONS
#
# 📦 ITEM GROUP 436 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-003 - OUTER ECCENTRIC BUSHING SH 5.5" SYMONS
#    • ST-SYM-5.5-003 - OUTER ECCENTRIC BUSHING ST 5.5" SYMONS
#
# 📦 ITEM GROUP 437 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-004 - INNER ECCENTRIC BUSHING SH 5.5" SYMONS
#    • ST-SYM-5.5-004 - INNER ECCENTRIC BUSHING ST 5.5" SYMONS
#
# 📦 ITEM GROUP 438 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-005 - SOCKET LINER SH 5.5" SYMONS
#    • ST-SYM-5.5-005 - SOCKET LINER ST 5.5" SYMONS
#
# 📦 ITEM GROUP 439 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-006 - SOCKET SEALING RING SH 5.5" SYMONS
#    • ST-SYM-5.5-006 - SOCKET SEALING RING ST 5.5" SYMONS
#
# 📦 ITEM GROUP 440 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-007 - DUSTING SPRING WITH SLEEVES SH 5.5" SYMONS
#    • ST-SYM-5.5-007 - DUSTING SPRING WITH SLEEVES ST 5.5" SYMONS
#
# 📦 ITEM GROUP 441 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-008 - MAIN SHAFT NUT (INCLUDING FEEDER PLATE) SH 5.5" SYMONS
#    • ST-SYM-5.5-008 - MAIN SHAFT NUT (INCLUDING FEEDER PLATE) ST 5.5" SYMONS
#
# 📦 ITEM GROUP 442 (2 items):
# --------------------------------------------------
#    • SH-SYM-5.5-009 - TOCH RING SH 5.5" SYMONS
#    • ST-SYM-5.5-009 - TOCH RING ST 5.5" SYMONS
#
# 📦 ITEM GROUP 443 (1 items):
# --------------------------------------------------
#    • SH-SYM-5.5-010 - MAIN SHAFT ASSEMBLY (COMPLETE, INCLUDING MAIN PLATE, SHAFT, MANTEL) SH 5.5" SYMONS
#
# 📦 ITEM GROUP 444 (1 items):
# --------------------------------------------------
#    • ST-SYM-5.5-001 - CONCAVE ST 5.5" SYMONS
#
# 📦 ITEM GROUP 445 (1 items):
# --------------------------------------------------
#    • ST-SYM-5.5-002 - MANTLE ST 5.5" SYMONS
#
# 📦 ITEM GROUP 453 (1 items):
# --------------------------------------------------
#    • ST-SYM-5.5-010 - MAIN SHAFT ASSEMBLY (COMPLETE, INCLUDING MAIN PLATE, SHAFT, MANTLE) ST 5.5" SYMONS
#
# 📦 ITEM GROUP 454 (1 items):
# --------------------------------------------------
#    • SU-P-H12 - SUPPORTING FLANGE
#
# 📦 ITEM GROUP 455 (2 items):
# --------------------------------------------------
#    • UCP-310 - BEARING WITH HOUSING
#    • UCP-320 - BEARING WITH HOUSING
#
# 📦 ITEM GROUP 456 (1 items):
# --------------------------------------------------
#    • W950/18 - OIL FILTER (LF3349)
#
# 📦 ITEM GROUP 457 (1 items):
# --------------------------------------------------
#    • WK731 - FILTER FUEL (FF5018)(BF988)
#
# 📦 ITEM GROUP 458 (1 items):
# --------------------------------------------------
#    • Y3-160M-4B3 - Electrical Motor 3ph/15hp/11kw/220-380v
#
# 📦 ITEM GROUP 459 (1 items):
# --------------------------------------------------
#    • YA00007606 - AIR ELEMENT INNER
#
# 📦 ITEM GROUP 460 (1 items):
# --------------------------------------------------
#    • YA00013067 - FILTER
#
# 📦 ITEM GROUP 461 (1 items):
# --------------------------------------------------
#    • YA00033064 - FILTER HYDRAULIC MAIN
#
# ============================================================
# Results saved to: Classified item.xlsx
# Total unique item groups: 446
# Total items processed: 644
# ============================================================
